# %% [markdown]
# ## Loading data into Pandas

# %%
import pandas as pd

#data = pd.read_csv('pokemon_data.csv')
 # print(data.to_string())
# df = pd.DataFrame(data)
# print(df.to_string())
# df.head(10)
# df.tail(5)

# df_xlsx = pd.read_excel('pokemon_data.xlsx')
# df_xlsx = pd.read_excel('pokemon_data.xlsx', sheet_name='Sheet2')
# print(df_xlsx.head())

# df = pd.read_csv('pokemon_data_del.txt', delimiter='\*')
# df = pd.read_csv('pokemon_data_del.txt')
# print(df.head(5))

# df = pd.read_csv('pokemon_data.txt', delimiter='\t')
# # df = pd.read_csv('pokemon_data.txt')
# print(df.head(5))

# df_json= pd.read_json('pokemon_data.json')
# print(df_json.head(5))

# df_json
print(df_json.columns)
# df_json['Name']
# df_json[['#','Name','Type 1','Defense']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 26
#       3 data = pd.read_csv('pokemon_data.csv')
#       4  # print(data.to_string())
#       5 # df = pd.DataFrame(data)
#       6 # print(df.to_string())
#    (...)
#      24
#      25 # df_json
# ---> 26 print(df_json.columns)
#
# NameError: name 'df_json' is not defined

# %% [markdown]
# ## Reading Data in Pandas

# %%
#### Read Headers
# df.columns

## Read each Column
# df[['Name', 'Type 1', 'HP']]

## Read Each Row
# print(df.iloc[0:5])
# df.head(4)

# a = ['apple','banana', 'mango']
# for i, r in enumerate(a):
#     print(i," : ", r)

# for index, row in df.iterrows():
#     print(index, row['Name'])

# df.loc[df['Attack'] == 49 ]
# df.loc[(df['Attack'] == 49) &&  (df['HP'] == 49) ]
# df.loc[(df['Type 1'] == "Grass") | (df['HP'] == 45) & (df['Defense'] > 60)] # not proper output 
# df.loc[((df['Type 1'] == "Grass") | (df['HP'] == 45)) & (df['Defense'] > 60)]
# df
#Read a specific location (R,C)
print(df.iloc[2,1])
print(df.head(5))
df['Name'][2]
# Out:
# Venusaur
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire    None  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# 'Venusaur'

# %% [markdown]
# ## Sorting/Describing Data

# %%
# df.sort_values(['Name','Type 1', 'HP'], ascending=True)

# df.sort_values(['Name','Type 1', 'HP'], ascending=[0,1,1])

# df.shape # to know exact rows and columns in the dataset
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark    None   40      65       40
# 632  571                  Zoroark     Dark    None   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark    None   65     150       60
# 392  359                    Absol     Dark    None   65     130       60
# 68    63                     Abra  Psychic    None   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 794       81       95     95           6       True
# 695       65       70     58           5      False
# 46        30       40     55           1      False
# 631       80       40     65           5      False
# 632      120       60    105           5      False
# ..       ...      ...    ...         ...        ...
# 393      115       60    115           3      False
# 392       75       60     75           3      False
# 68       105       55     90           1      False
# 511      132      105     30           4      False
# 510       92       85     60           4      False
#
# [800 rows x 12 columns]

# %% [markdown]
# ## Making changes to the data

# %%
 # df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

# df = df.drop(columns=['Total'])

df['Total'] = df.iloc[:, 4:10].sum(axis=1)
# df
# df.columns
# cols = list(df.columns)


# df = df[cols[0:4] + [cols[-1]]+cols[4:12]]
# df
# dff= df[['Sp. Atk', 'Sp. Def', 'Speed','HP','Defense','Attack'] ]
# print(dff)
# print(df)
# df.head(5)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire    None  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# 1         80       80     60           1      False    405
# 2        100      100     80           1      False    525
# 3        122      120     80           1      False    625
# 4         60       50     65           1      False    309
# ..       ...      ...    ...         ...        ...    ...
# 795      100      150     50           6       True    600
# 796      160      110    110           6       True    700
# 797      150      130     70           6       True    600
# 798      170      130     80           6       True    680
# 799      130       90     70           6       True    600
#
# [800 rows x 13 columns]

# %%
45+49+49+65+65+45
# Out:
# 318

# %% [markdown]
# ## Saving our Data (Exporting into Desired Format)

# %%
df.to_csv('poke.csv', index=False)
# df.to_csv('poke.csv')

# dff.to_csv('hp_to_speed.csv', index=False)
# df.to_csv('modified.csv', index=False)

df.to_excel('poke.xlsx', index=False)

df.to_csv('poke.txt', index=False, sep='*')
dff.to_json('poke.json')
