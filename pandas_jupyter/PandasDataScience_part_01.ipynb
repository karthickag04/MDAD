# %% [markdown]
# ## Loading data into Pandas

# %%
import pandas as pd

# data = pd.read_csv('pokemon_data.csv')

# df = pd.DataFrame(data)

# df.head(5)
# df.tail(5)

# df_xlsx = pd.read_excel('pokemon_data.xlsx')
# df_xlsx = pd.read_excel('pokemon_data.xlsx', sheet_name='Sheet2')
# print(df_xlsx.head())

# df = pd.read_csv('pokemon_data.txt', delimiter='\t')
# # df = pd.read_csv('pokemon_data.txt')

# print(df.head(5))

# df['Name']
# df[['HP','Name']]

df_json= pd.read_json('pokemon_data.json')
df_json['Name']
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %% [markdown]
# ## Reading Data in Pandas

# %%
#### Read Headers
# df.columns

## Read each Column
# df[['Name', 'Type 1', 'HP']]

## Read Each Row
# print(df.iloc[0:4])
# df.head(4)

# a = ['apple','banana', 'mango']
# for i, r in enumerate(a):
#     print(i," : ", r)

# for index, row in df.iterrows():
#     print(index, row['Name'])

# df.loc[df['Type 1'] == "Grass" ]
# df.loc[(df['Type 1'] == "Grass") | (df['HP'] == 45) & (df['Defense'] > 60)] # not proper output 
# df.loc[((df['Type 1'] == "Grass") | (df['HP'] == 45)) & (df['Defense'] > 60)]
# df
#Read a specific location (R,C)
# print(df.iloc[2,1])
# print(df.head(5))
# df['Name'][2]
# Out:
# Venusaur
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# 'Venusaur'

# %% [markdown]
# ## Sorting/Describing Data

# %%
# df.sort_values(['Name','Type 1', 'HP'], ascending=False)

# df.sort_values(['Name','Type 1', 'HP'], ascending=[0,1,1])

# df.shape # to know exact rows and columns in the dataset
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ## Making changes to the data

# %%
 # df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

# df = df.drop(columns=['Total'])

# df['Total'] = df.iloc[:, 4:10].sum(axis=1)
# df
# df.columns
# cols = list(df.columns)


# df = df[cols[0:4] + [cols[-1]]+cols[4:12]]
# df
dff= df[['Sp. Atk', 'Sp. Def', 'Speed','HP','Defense','Attack'] ]
print(dff)
print(df)
# df.head(5)
# Out:
#      Sp. Atk  Sp. Def  Speed  HP  Defense  Attack
# 0         65       65     45  45       49      49
# 1         80       80     60  60       63      62
# 2        100      100     80  80       83      82
# 3        122      120     80  80      123     100
# 4         60       50     65  39       43      52
# ..       ...      ...    ...  ..      ...     ...
# 795      100      150     50  50      150     100
# 796      160      110    110  50      110     160
# 797      150      130     70  80       60     110
# 798      170      130     80  80       60     160
# 799      130       90     70  80      120     110
#
# [800 rows x 6 columns]
#        #                   Name   Type 1  Type 2  Generation  Legendary  \
# 0      1              Bulbasaur    Grass  Poison           1      False
# 1      2                Ivysaur    Grass  Poison           1      False
# 2      3               Venusaur    Grass  Poison           1      False
# ...

# %%
45+49+49+65+65+45
# Out:
# 318

# %% [markdown]
# ## Saving our Data (Exporting into Desired Format)

# %%
# dff.to_csv('hp_to_speed.csv', index=False)
# df.to_csv('modified.csv', index=False)

# # dff.to_excel('modifieddata.xlsx', index=False)

# dff.to_csv('modified.txt', index=False, sep='\t')
dff.to_json('modifiedjson.json')
