# %%
from IPython.display import Image, display

# Path to the image file
image_path = "images/0_What_is_probability.png"
image_path1 = "images/1_.png"
image_path2 = "images/2_Equally_likely.png"
image_path3 = "images/2a_Equally_likely.png"
image_path4 = "images/2b_Not_Equally_likely.png"
image_path5 = "images/3_Conditional_prob___.png"
image_path6 = "images/3a_Conditional_prob_1.png"
image_path7 = "images/4_Mutually_Exclusive.png"
image_path8 = "images/4a_addition_.PNG"
image_path9 = "images/4b_addition_a.PNG"
image_path10 = "images/5_Independent_event.png"
image_path11 = "images/5a_multiplication_.PNG"
image_path12 = "images/5b_multiplication_a.PNG"
image_path13 = "images/5c_Multiplication_rule.png"
image_path14 = "images/6.Summary_.PNG"
# image_path15 = "images/"

# Display the image

display(Image(filename=image_path))
display(Image(filename=image_path1))
display(Image(filename=image_path2))
display(Image(filename=image_path3))
display(Image(filename=image_path4))
display(Image(filename=image_path5))
display(Image(filename=image_path6))
display(Image(filename=image_path7))
display(Image(filename=image_path8))
display(Image(filename=image_path9))
display(Image(filename=image_path10))
display(Image(filename=image_path11))
display(Image(filename=image_path12))
display(Image(filename=image_path13))
display(Image(filename=image_path14))
